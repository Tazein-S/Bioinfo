# %% [markdown]
# An event is simply a collection of outcomes. Because outcomes are distinct, the probability of an event can be written as the sum of the probabilities of its constituent outcomes. For our colored ball example, let A be the event "Y is blue." Pr(A) is equal to the sum of the probabilities of two different outcomes: Pr(X=blue and Y=blue)+Pr(X=red and Y=blue), or 310+110=25.
#
# Given: Three positive integers k, m, and n, representing a population containing k+m+n organisms: k individuals are homozygous dominant for a factor, m are heterozygous, and n are homozygous recessive.
#
# Return: The probability that two randomly selected mating organisms will produce an individual possessing a dominant allele (and thus displaying the dominant phenotype). Assume that any two organisms can mate.

# %%
# k is homo dominant
# m is hetero
# n is homo recessive

k,m,n = 22,17,16
total = k + m + n
total_dom = 0

# both parents are k 
total_dom += ((k/total) * ((k-1)/(total-1))) #all the kk offsprings will 100% be dominant

# both parents are m 
total_dom += ((m/total) * ((m-1)/(total-1))) * 0.75 

# both parents are n 
total_dom += ((n/total) * ((n-1)/(total-1)))* 0

# one parent is k and other is m 
total_dom += (((k/total) * (m/(total-1))) + (((m/total) * k/(total-1))))

# one parent is k and other is n 
total_dom += ((((k/total) * (n/(total-1))) + ((m/total) * (k/(total-1)))) )

# one parent is m and other is n 
total_dom += ((((m/total) * (n/(total-1)))* (0.50)) + (((n/total) * (m/(total-1))) * (0.50)))

print(total_dom)
# Out:
# 0.8121212121212121

# %% [markdown]
# ##### Kept getting this problem wrong so the answer is below (from https://saradoesbioinformatics.blogspot.com/2016/06/mendels-first-law.html)
#
# ![image.png](attachment:image.png)

# %%
k = 20                                             
m = 18                                                      
n = 17                                                       
pop = k + m + n                                               
prob = (4*(k*(k-1)+2*k*m+2*k*n+m*n)+3*m*(m-1))/(4*pop*(pop-1))
print(prob)
# Out:
# 0.7796296296296297
